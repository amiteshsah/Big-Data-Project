# %%
# %matplotlib inline
# Coorelation between data sets
import pandas as pd
df=pd.read_csv('/Users/amitesh/Desktop/Courses/Big_Data/BigDataProject/part2/Analysis/NTA_coordinate_crime.csv')
df
# Out:
#       NTA                                      Lat_Lon_crime
# 0    MN31  [[-73.957202162000002, 40.764149789000001], [-...
# 1    MN32  [[-73.947327823999998, 40.783910564000003], [-...
# 2    MN33  [[-73.941132468000006, 40.786731897999999], [-...
# 3    BX62  [[-73.849792042000004, 40.893937129999998], [-...
# 4    MN34  [[-73.935624767999997, 40.809858783000003], [-...
# 5    BX63  [[-73.915427441000006, 40.838571954999999], [-...
# 6    MN35  [[-73.929845986000004, 40.853400301000001], [-...
# 7    MN36  [[-73.936252607, 40.840783858000002], [-73.942...
# 8    SI54  [[-74.149594012999998, 40.539474059], [-74.151...
# 9    MN40  [[-73.951893718999997, 40.781705793], [-73.950...
# 10   BX75  [[-73.887702994999998, 40.837442176000003], [-...
# 11   MN50  [[-73.976522430000003, 40.733589823999999], [-...
# 12   QN01  [[-73.793318760000005, 40.697768666999998], [-...
# 13   QN02  [[-73.776233907000005, 40.679980737999998], [-...
# ...

# %%
nta_list=['BX55','SI45']
df_nta=df[df['NTA'].isin(nta_list)]
df_nta
# Out:
#       NTA                                      Lat_Lon_crime
# 189  BX55  [[-73.862056588000002, 40.831494004], [-73.880...
# 192  SI45  [[-74.098474167999996, 40.576913597000001], [-...

# %%
for nta in nta_list:
    for lat_lon in df_nta[nta]:
